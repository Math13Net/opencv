# %% [markdown]
# ### 📜 Licence d'utilisation
# Ce notebook est mis à disposition sous licence **Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International**.
#
# **Auteur** : Christie Vassilian

# %% [markdown]
# ---

# %% [markdown]
# # 🧠 Mise en pratique des fonctions d’activation
# Dans ce notebook, nous allons entraîner un petit réseau de neurones pour reconnaître des chiffres manuscrits (base MNIST réduite ou digits).
# Nous testerons successivement différentes fonctions d’activation : **sigmoïde, ReLU, Leaky ReLU, Swish**, et observerons l’impact sur l’apprentissage.
#
# Les cellules de code sont préparées pour être facilement modifiées. Les élèves sont invités à **exécuter, observer, comparer et analyser**.

# %% [markdown]
# # 🧮 Comment évaluer une fonction d’activation ?
# **Critères principaux :**
# - 🔁 Convergence de l’apprentissage (rapidité)
# - 🎯 Accuracy finale (qualité de prédiction)
# - 🧠 Stabilité du modèle (éviter saturation ou neurones morts)
# - 📉 Forme des courbes `loss` / `accuracy` au fil des epochs

# %% [markdown]
# # 🎯 Synthèse des Résultats

# %% [markdown]
# ### ✍️ Bloc de réponse à remplir (Sigmoid)
# **1. Accuracy finale :**
#
# **2. Forme de la courbe d’accuracy :**
#
# **3. Remarques personnelles sur cette fonction d’activation :**

# %% [markdown]
# ### ✍️ Bloc de réponse à remplir (ReLU)
# **1. Accuracy finale :**
#
# **2. Forme de la courbe d’accuracy :**
#
# **3. Remarques personnelles sur cette fonction d’activation :**

# %% [markdown]
# ### ✍️ Bloc de réponse à remplir (tanh)
# **1. Accuracy finale :**
#
# **2. Forme de la courbe d’accuracy :**
#
# **3. Remarques personnelles sur cette fonction d’activation :**

# %% [markdown]
# ### ✍️ Bloc de réponse à remplir (Swish)
# **1. Accuracy finale :**
#
# **2. Forme de la courbe d’accuracy :**
#
# **3. Remarques personnelles sur cette fonction d’activation :**

# %% [markdown]
# ### 📝 Tableau de comparaison à compléter
# Complète ce tableau au fur et à mesure de tes expérimentations :
#
# | Fonction d’activation | Accuracy finale | Vitesse de convergence | Remarques |
# |------------------------|------------------|--------------------------|-----------|
# | Sigmoïde               |                  |                          |           |
# | ReLU                   |                  |                          |           |
# | Tanh                   |                  |                          |           |
# | Swish                  |                  |                          |           |

# %% [markdown]
# ---

# %% [markdown]
# # 👁️ Chargement et Visualisation des données MNIST

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Chargement et prétraitement
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, 28*28) / 255.0
X_test = X_test.reshape(-1, 28*28) / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
import matplotlib.pyplot as plt
(X_train_img, _), (_, _) = mnist.load_data()
plt.figure(figsize=(10,4))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_train_img[i], cmap='gray')
    plt.axis('off')
    plt.title(f"Label : {i}")
plt.suptitle("Exemples d'images du dataset MNIST", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🏗️ Construction d’un modèle simple

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

def build_model(activation):
    model = Sequential([
        Dense(32, input_shape=(784,), activation=activation), # Corrected input shape
        Dense(16, activation=activation),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer=Adam(0.01),
                  loss=CategoricalCrossentropy(),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ---

# %% [markdown]
# # ⚙️ Entraînement avec activation : `sigmoid`

# %% [markdown]
# Nous allons analyser ensemble les résultats obtenus avec la fonction **sigmoïde**.
#
# ## Étapes :
# 1. Entraîner le modèle avec `activation='sigmoid'`
# 2. Observer l’évolution de l’accuracy
# 3. Comparer les performances avec les autres fonctions
# 4. Réfléchir aux avantages et inconvénients

# %%
model = build_model('sigmoid')
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy avec activation sigmoid :", test_acc)

# %%
model = build_model('sigmoid')
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), verbose=0)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title("Sigmoïde - Courbes d'accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## ❓ Analyse pour la Sigmoid
# 1. Quelle est l’accuracy finale obtenue ?
# 2. Comment évolue la courbe d’apprentissage ? Est-elle régulière, lente, rapide ?
# 3. As-tu remarqué un plateau, un pic, une stagnation ?
# 4. Quels avantages ou limites observes-tu pour cette fonction dans ce contexte MNIST ?

# %% [markdown]
# ---

# %% [markdown]
# # 🔁 À vous d’analyser les autres fonctions d’activation !
# Refais l’analyse ci-dessus pour :
# - `ReLU`
# - `Tanh`
# - `Swish`

# %% [markdown]
# ---

# %% [markdown]
# # ⚙️ Entraînement avec activation : `relu`

# %%
model = build_model('relu')
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy avec activation relu :", test_acc)

# %% [markdown]
# ---

# %% [markdown]
# # ⚙️ Entraînement avec activation : `tanh`

# %%
model = build_model('tanh')
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy avec activation tanh :", test_acc)

# %% [markdown]
# ---

# %% [markdown]
# # ⚙️ Entraînement avec activation : Swish (custom)

# %%
from tensorflow.keras.layers import Activation
from tensorflow.keras.utils import get_custom_objects
import tensorflow as tf

def swish(x):
    return x * tf.keras.backend.sigmoid(x)
get_custom_objects().update({'swish': Activation(swish)})

model = build_model('swish')
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), verbose=0)
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy avec activation swish :", test_acc)

# %% [markdown]
# ---

# %% [markdown]
# # 📉 Pour aller plus loin : Courbes de perte (loss)
# Observer la courbe de loss peut aider à comprendre la vitesse de convergence et les risques de surapprentissage.
#
# ```python
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='val')
# plt.title("Évolution de la perte (loss)")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.legend()
# plt.grid()
# plt.show()
# ```
#
# 🔎 *On peut également explorer une **matrice de confusion** dans un TD ultérieur, afin d’étudier plus finement les erreurs du modèle.*

# %% [markdown]
# ---

# %% [markdown]
# # ✅ Partie professeur – Réponses détaillées et relecture complète
# Cette partie reprend toute l’activité pas à pas pour que tu puisses vérifier ta compréhension et tes résultats.
# Tu peux t'en servir comme **correction guidée** ou comme **support pour refaire toute l’analyse** si tu as besoin d’aide.

# %% [markdown]
# ### 🔹 Analyse de la fonction d’activation : Sigmoïde
# - La courbe d’accuracy monte lentement mais sûrement.
# - L'accuracy finale se stabilise autour de **91% à 93%**.
# - Cette lenteur vient du fait que la **sigmoïde sature** quand les entrées sont grandes ou petites.
# - La dérivée devient alors presque nulle (phénomène de **vanishing gradient**).

# %% [markdown]
# ### 🔹 Analyse de la fonction d’activation : ReLU
# - L’accuracy monte beaucoup plus vite (~95% à 97%).
# - La convergence est rapide et stable.
# - Attention : certains neurones peuvent rester bloqués si leur entrée reste négative (**neurones morts**).
# - Mais dans un petit réseau, cela reste rare.

# %% [markdown]
# ### 🔹 Analyse de la fonction d’activation : tanh
# - Similaire à la sigmoïde mais centrée en 0.
# - L’apprentissage est plus rapide que sigmoïde mais moins rapide que ReLU.
# - L’accuracy finale est souvent autour de **94-96%**.

# %% [markdown]
# ### 🔹 Analyse de la fonction d’activation : Swish
# - Fonction récente, douce et efficace.
# - Comporte une partie négative mais non nulle (évite les neurones morts).
# - Bonne convergence, souvent entre **97-98% d’accuracy** sur MNIST.
# - Plus lente à calculer que ReLU, mais très performante.

# %% [markdown]
# ### 📊 Résumé comparatif (corrigé indicatif)
# | Fonction d’activation | Accuracy finale | Vitesse de convergence | Remarques |
# |------------------------|------------------|--------------------------|-----------|
# | Sigmoïde               | 91–93 %          | Lente                   | Saturation, stable       |
# | ReLU                   | 95–97 %          | Rapide                  | Simple et efficace       |
# | Tanh                   | 94–96 %          | Moyenne                 | Bon compromis            |
# | Swish                  | 97–98 %          | Bonne                   | Fluide, moderne          |

# %% [markdown]
# ## 📉 Pour aller plus loin : courbe de perte (loss) – Explication
# - Le loss correspond à l’erreur globale du modèle à chaque epoch.
# - Plus il diminue rapidement et régulièrement, mieux la fonction d’activation permet l’apprentissage.
# - On compare souvent `loss` et `val_loss` pour détecter un **surapprentissage** (overfitting).
# - Une fonction d’activation efficace fera **descendre la loss rapidement**.
# - Si la loss de validation remonte, cela peut signaler une **surcharge (overfit)**.

# %% [markdown]
# ### 📜 Licence d'utilisation
# Ce notebook est mis à disposition sous licence **Creative Commons Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 4.0 International**.
#
# **Auteur** : Christie Vassilian
